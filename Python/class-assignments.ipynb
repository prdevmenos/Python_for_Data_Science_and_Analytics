# %%
# Lists

movie = ['dhurandhar', 'avengers', 'black-panther', 'jawan', 'conjuring']

# %%
movie
# Out:
# ['dhurandhar', 'avengers', 'black-panther', 'jawan', 'conjuring']

# %%
movie.append('anabelle')
movie
# Out:
# ['dhurandhar', 'avengers', 'black-panther', 'jawan', 'conjuring', 'anabelle']

# %%
movie.pop(2)
# Out:
# 'black-panther'

# %%
movie
# Out:
# ['dhurandhar', 'avengers', 'jawan', 'conjuring', 'anabelle']

# %%
movie.remove('anabelle')
movie
# Out:
# ['dhurandhar', 'avengers', 'jawan', 'conjuring']

# %%
movie.sort()
movie
# Out:
# ['avengers', 'conjuring', 'dhurandhar', 'jawan']

# %%
# 2 june
#1

movies = ["black panther", "avengers", "dhurandhar", "inside edge","titanic"]
movies.append("jawan")
movies
# Out:
# ['black panther', 'avengers', 'dhurandhar', 'inside edge', 'titanic', 'jawan']

# %%
movies.pop(2)
movies
# Out:
# ['black panther', 'avengers', 'inside edge', 'titanic', 'jawan']

# %%
movies.sort()
movies
# Out:
# ['avengers', 'black panther', 'inside edge', 'jawan', 'titanic']

# %%
Tup1 = tuple(movies)
Tup1
# Out:
# ('avengers', 'black panther', 'inside edge', 'jawan', 'titanic')

# %%
fruit = {'mango', 'apple', 'grapes', 'lichi'}
fruit
# Out:
# {'apple', 'grapes', 'lichi', 'mango'}

# %%
fruit.add('papaya')
fruit
# Out:
# {'apple', 'grapes', 'lichi', 'mango', 'papaya'}

# %%
f1 = {'apple'}
f1.issubset(fruit)
# Out:
# True

# %%
print(fruit)
# Out:
# {'grapes', 'apple', 'papaya', 'mango', 'lichi'}

# %%
# dict question

dict1 = {"m1" : 8.71, "m2" : 8.9, "m3" : 9.1, "ml" : 9.5}
dict1
# Out:
# {'m1': 8.71, 'm2': 8.9, 'm3': 9.1, 'ml': 9.5}
