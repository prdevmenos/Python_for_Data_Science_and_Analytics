# %%
name = "Prasanna"
age = 25
height = 5.11
print(name)
print(age)
print(height)
print(f"My name is {name} and I am {age} year old, {height} long")
# Out:
# Prasanna
# 25
# 5.11
# My name is Prasanna and I am 25 year old, 5.11 long

# %%
num1 = 456
num2 = 123

# Addition
sum = num1 + num2
print(sum)
print("-------------------")
# Substraction
difference = num1 - num2
print(difference)
print("-------------------")
# Multiplication
product = num1 * num2
print(product)
print("-------------------")
# Division
div = num1/num2
print(div)
print("-------------------")
# Floor Division
floor = num1//num2
print(floor)
print("-------------------")
# Exponential
exp1 = num1 ** 2
exp2 = num2 ** 4
print(exp1)
print(exp2)
print("-------------------")
# Modulus
mod1 = num1 % num2
mod2 = num1 % 5
mod3 = num2 % 7
print(mod1)
print(mod2)
print(mod3)
print("-------------------")
# Out:
# 579
# -------------------
# 333
# -------------------
# 56088
# -------------------
# 3.707317073170732
# -------------------
# 3
# -------------------
# 207936
# 228886641
# -------------------
# 87
# 1
# 4
# -------------------

# %%
a = 34
print(a)
# Out:
# 34

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(a)
# Out:
# int

# %%
print(type(None))
print(type(True))
print(type(-0.190))
print(type(0.034))
print(type('raj'))
print(type('r'))
print(type("Rakesh"))
print(type(False))
print(type(90))
print(type(-256))
# Out:
# <class 'NoneType'>
# <class 'bool'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>
# <class 'int'>

# %%
print("true")
# Out:
# true

# %%
"25" + "10"
# Out:
# '2510'

# %%
True is True
# Out:
# True

# %%
# Time conversion seconds to minutes
total_seconds = 985
minutes = total_seconds // 60
print("Minutes are ",minutes)
# Out:
# Minutes are  16

# %%
# Volume of cube : side^3

side = 91
volume = side ** 3
print("Volume of cube is ",volume)

# Area of square : side^2

side = 9
area = side ** 2
print("Area of Square is ",area)
# Out:
# Volume of cube is  753571
# Area of Square is  81

# %%
# Volume of Cuboid : l X b X h

length = 12
breadth = 5
height = 7

volume = length * breadth * height
print("Volume of Cuboid : ",volume)

# Area of Rectangle : l X b

length1 = 20
breadth1 = 12

area1 = length1 * breadth1
print("Area of Rectangle : ",area1)

# Area of Rectangle angled Triangle = 1/2 X base X altitude

base = 8
altitude = 11

area2 = 1/2 * (base * altitude)
print("Area of Right angled triangle : ",area2)
# Out:
# Volume of Cuboid :  420
# Area of Rectangle :  240
# Area of Right angled triangle :  44.0

# %%
name = "Prasanna"
age = 25
height = 5.11
print("My name is",name, "Age ",age, "Height is ",height)
# Out:
# My name is Prasanna Age  25 Height is  5.11

# %% [markdown]
# Assignment - 2

# %%
# Write a Python program to calculate the length of a string

s1 = "Data Analytics"
len(s1)
# Out:
# 14

# %%
# Write a Python program to count the number of characters (character frequency) in a string.
# Sample String : google.com'

s2 = "google.com"
print(s2.count('g'))
print(s2.count('o'))
print(s2.count('l'))
print(s2.count('e'))
print(s2.count('c'))
print(s2.count('m'))
# Out:
# 2
# 3
# 1
# 1
# 1
# 1

# %%
# Write a Python program to get a string made of the first 2 and last 2 characters of a given string. 
# If the string length is less than 2, return the empty string instead.

s3 = "Resource"
print(s3[:2] + s3[6:])
# Out:
# Rece

# %%
# Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$',
# except the first char itself.

s4 = "resource"
s4[0] + s4[1:].replace('r','$')
# Out:
# 'resou$ce'

# %%
# Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.

s5 = 'raj'
s6 = 'mohan'
s7 = s5.replace('ra','mo')
s8 = s6.replace('mo','ra')
s9 = s7 + ' ' + s8
s9
# Out:
# 'moj rahan'

# %%
# Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing',
# add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.

# %%
L1 = [12,5,6,9,0,34,67,98,"ethans","python","Java","SQL"]
L1
# Out:
# [12, 5, 6, 9, 0, 34, 67, 98, 'ethans', 'python', 'Java', 'SQL']

# %%
print(L1)
# Out:
# [12, 5, 6, 9, 0, 34, 67, 98, 'ethans', 'python', 'Java', 'SQL']

# %%
L1.append(245)

# %%
L1
# Out:
# [12, 5, 6, 9, 0, 34, 67, 98, 'ethans', 'python', 'Java', 'SQL', 245]

# %%
dir(L1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
L1.count("ethans")
# Out:
# 1

# %%
L1.index("Java")
# Out:
# 10

# %%
len(L1)
# Out:
# 13

# %%
L1[10]
# Out:
# 'Java'

# %%
L1[-1]
# Out:
# 245

# %%
L1[1:2]
# Out:
# [5]

# %%
L1[6:12]
# Out:
# [67, 98, 'ethans', 'python', 'Java', 'SQL']

# %%
L1[1:12:3] # slicing -> start:stop:end
# Out:
# [5, 0, 98, 'Java']

# %%
L1["ethans"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 L1["ethans"]
#
# TypeError: list indices must be integers or slices, not str

# %%
L1.index("ethans")

# %%
L1[-8]

# %%
print(L1)

# %%
L1.index(98)

# %%
# L1.extend(90) # extend() only takes iterable object.

# %%
L1.extend("string")

# %%
L1

# %%
# L1.remove("string") # not present in list

# %%
len(L1)

# %%
L1.remove("g")

# %%
L1

# %%
L1.remove("n")

# %%
L1.remove("i")

# %%
L1.remove("r")
L1.remove("t")

# %%
L1.remove("s")
L1

# %%
L2 = L1.copy()
L2

# %%
print(L1)
print(L2)

# %%
L2.clear()

# %%
L2

# %%
# L1.insert(69) # expects two arguments (argument, index number)
L1

# %%
L1.insert(3, 69)
L1

# %%
L1.insert(14, "cpp")
L1

# %%
L1.insert(12, 'c')
L1

# %%
# L3 = L1.sort() # '>' means a character not supported sort()
L1

# %%
L1

# %%
len(L1)

# %%
L1.pop(-3)

# %%
L1

# %%
L1.pop(-2)

# %%
L1

# %%
L1.sort()

# %%
dir(L1)

# %%
L1.clear()
L1

# %%
L1 = [12,56, 81, 90,71,65,91]
L1.sort()
L1

# %%
L1.sort(reverse=True)
L1

# %%
L1.count(90)

# %%
L2 = ["Apple","Banana","Orange","Grapes","apple","banana","orange","grapes"]
L2.sort()
L2

# %%
L2.reverse()
L2

# %%
L3 = L2.reverse()
L3

# %%
L2

# %%
T1 = tuple(L2)
T1

# %%
dir(T1)

# %%
T1.count("apple")

# %%
T1.count("Apple")

# %%
T1[1:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 T1[1:5]
#
# NameError: name 'T1' is not defined

# %%
len([1,2,3,4])
# Out:
# 4

# %%
list34 = ['dzire','fortuner','skoda']
list34
# Out:
# ['dzire', 'fortuner', 'skoda']

# %%
list34.insert(1,'swift')
list34
# Out:
# ['dzire', 'swift', 'fortuner', 'skoda']

# %%
dict = {'name' : 'ram',
        'age' : 23,
        'salary' : 50000
}
dict
# Out:
# {'name': 'ram', 'age': 23, 'salary': 50000}

# %%
dict.get('missing')

# %%
dict
# Out:
# {'name': 'ram', 'age': 23, 'salary': 50000}

# %%
# Write a Python program to find those numbers which are divisible by 7 and multiples of 5, between 1500 and 2700 (both included).

for i in range(1500,2701):
    if i%7 == 0 and i%5 == 0:
        print(i)
# Out:
# 1505
# 1540
# 1575
# 1610
# 1645
# 1680
# 1715
# 1750
# 1785
# 1820
# 1855
# 1890
# 1925
# 1960
# 1995
# 2030
# 2065
# 2100
# 2135
# 2170
# 2205
# 2240
# 2275
# 2310
# 2345
# 2380
# 2415
# 2450
# 2485
# 2520
# 2555
# 2590
# 2625
# 2660
# 2695

# %%
L1 = []
for i in range(1500,2701):
    if i % 7 == 0 and i % 5 == 0:
        L1.append(int(str(i)))
print(L1)
# Out:
# [1505, 1540, 1575, 1610, 1645, 1680, 1715, 1750, 1785, 1820, 1855, 1890, 1925, 1960, 1995, 2030, 2065, 2100, 2135, 2170, 2205, 2240, 2275, 2310, 2345, 2380, 2415, 2450, 2485, 2520, 2555, 2590, 2625, 2660, 2695]

# %%
L2 = []
for i in range(1500, 2701):
    if i % 7 == 0 and i % 5 == 0:
        L2.append(str(i))
print(L2)
print(' '.join(L2))
# Out:
# ['1505', '1540', '1575', '1610', '1645', '1680', '1715', '1750', '1785', '1820', '1855', '1890', '1925', '1960', '1995', '2030', '2065', '2100', '2135', '2170', '2205', '2240', '2275', '2310', '2345', '2380', '2415', '2450', '2485', '2520', '2555', '2590', '2625', '2660', '2695']
# 1505 1540 1575 1610 1645 1680 1715 1750 1785 1820 1855 1890 1925 1960 1995 2030 2065 2100 2135 2170 2205 2240 2275 2310 2345 2380 2415 2450 2485 2520 2555 2590 2625 2660 2695

# %%
# Temperature Converter

# Write a Python program to convert temperatures to and from Celsius and Fahrenheit.

# [ Formula : c/5 = f-32/9 [ where c = temperature in celsius and f = temperature in fahrenheit ]]

# Expected Output :

# 60°C is 140 in Fahrenheit
# 45°F is 7 in Celsius 

c = int(input('Enter temperature in celsius : '))
f = int(input('Enter temperature in fahrenheit : '))

result =

# %%
range(5)
# Out:
# range(0, 5)

# %% [raw]
# True + False

# %%
# Write a Python program that prints all the numbers from 0 to 6 except 3 and 6.

# Note : Use 'continue' statement.

# Expected Output : 0 1 2 4 5

for i in range(0,7):
    #print(i)
    if i == 3 or i == 6:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
# Write a Python program to construct the following pattern, using a nested for loop.

# * 
# * * 
# * * * 
# * * * * 
# * * * * * 
# * * * * 
# * * * 
# * * 
# *

for i in range(1,6):
    for j in range(0,i):
        print('*',end = ' ')
    print()
for x in range(4,0,-1):
    for y in range(x):
        print('*',end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
# Write a Python program that accepts a word from the user and reverses it.

count = 1
str2 = input('Enter String.')
for i in str2:
    count = count/10

# %% [markdown]
# Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
#
# Sample String : 'abc'
#
# Expected Result : 'abcing'
#
# Sample String : 'string'
#
# Expected Result : 'stringly'

# %%
#str1 = input("Enter String : ")

# %% [markdown]
# ### OOP's Practice

# %%
class A:
    name = 'Ram'
    Id = 103
    std = 11

AA = A()
print(AA.name)
print(AA.Id)
print(AA.std)
# Out:
# Ram
# 103
# 11

# %%
AA.name = "Raj"
print(AA.name)
# Out:
# Raj

# %%
class B:
    Id = 234
    std = 12
    def name(self, n):
        print("Name of student is ",n)

# %%
BB = B()
BB.Id
# Out:
# 234

# %%
BB.name("Rakesh")
# Out:
# Name of student is  Rakesh

# %%
BB.std
# Out:
# 12
