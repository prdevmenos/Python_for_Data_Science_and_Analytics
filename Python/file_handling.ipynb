# %% [markdown]
# ## File handling
# File handling is the process of creating, reading, writing, and managing files in a program. It is a fundamental skill in programming that helps to store, retrieve, and manipulate data efficiently. Proper file handling ensures that programs are robust, secure, and maintainable, especially when dealing with user-generated content, large datasets, or configuration files. Proper file handling also enables structured data organization, which is essential for large-scale and repeated operations.

# %% [markdown]
# # File handling methods
# Open (file, mode)
# This function is used to open a file to read, write, or modify its contents. It creates a connection between the program and the file.
#
# file: The name of the file (including its path) to open.
# mode: Determines how to interact with the file:
#
# ‘r’: Read mode (default) – Opens the file only for reading.
#
# ‘w’: Write mode – Opens the file for writing, overwriting its content if it exists.
#
# ‘a’: Append mode – Opens the file to add content at the end without overwriting.
#
# ‘b’: Binary mode – Used for non-text files (e.g., images).

# %%
F = open("Python.txt", 'r')

# %%
F
# Out:
# <_io.TextIOWrapper name='Python.txt' mode='r' encoding='cp65001'>

# %%
F.read()
# Out:
# 'Hello, We all are gathered to learn Data Science.\nfirst step to learn is python programming language,\nthen SQL, PowerBI, Tableau, etc\n\nAfter that, we will cover Machine Learning part like\nlibraries.'

# %%
F.read()
# Out:
# ''

# %%
F.seek(0) # To move cursor from beginning.
# Out:
# 0

# %%
F.readline()
# Out:
# 'Hello, We all are gathered to learn Data Science.\n'

# %%
F.readlines()
# Out:
# ['first step to learn is python programming language,\n',
#  'then SQL, PowerBI, Tableau, etc\n',
#  '\n',
#  'After that, we will cover Machine Learning part like\n',
#  'libraries.']

# %%
type(F.readlines())
# Out:
# list

# %%
type(F.readline())
# Out:
# str

# %%
FF = open('Python.txt') # by default file opens in read mode
FF.read()
# Out:
# 'Gooe Morining, To all Today we are here to gathered for learning python programming language.'

# %%
FF = open('Python.txt','w') # write mode

# %%
FF.write('Today we are learning file handling in python.')
# Out:
# 46

# %%
FF.close()

# %%
FF = open('Python.txt')
FF.read()
# Out:
# 'Today we are learning file handling in python.'

# %%
FFF = open('Python.txt','a')
FFF.write(' After that we are learning functions.')
# Out:
# 38

# %%
FFF.close()

# %%
GG = open('Python.txt')
GG.read()
# Out:
# 'Today we are learning file handling in python. After that we are learning functions.'

# %%
X = open('X File.txt','x')
X.write('Happy Birthday!')
X.close()

# %%
XX = open('X File.txt')
XX.read()
# Out:
# 'Happy Birthday!'

# %%
XX.close()

# %%
import os
os.remove('X File.txt')
