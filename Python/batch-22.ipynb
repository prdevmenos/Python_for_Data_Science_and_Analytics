# %%
print("hello")
# Out:
# hello

# %%
x = 1
#y = 2
print(x + y)
# Out:
# 3

# %% [markdown]
# # # is used to comment the text and python codes

# %%
print("xyz")
# Out:
# xyz

# %% [markdown]
# Variable

# %%
x = 10

# %%
x
# Out:
# 10

# %%
print(x)
# Out:
# 10

# %%
x = 100

# %%
A1 = 3450

# %%
A1
# Out:
# 3450

# %%
A 1 = 234598
# Out:
#   Cell In[21], line 1
#     A 1 = 234598
#       ^
# SyntaxError: invalid syntax

# %%
A_1 = 234598

# %%
A_1
# Out:
# 234598

# %%
@34 = 4567
# Out:
#   Cell In[24], line 1
#     @34 = 4567
#      ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x34 = 4567

# %%
print(x34)
# Out:
# 4567

# %% [markdown]
# name = "Ethans"

# %%
name
# Out:
# 'Ethans'

# %%
print(name)
# Out:
# Ethans

# %% [markdown]
# Datatype

# %%
# datatype
# numbers : int, float

# %%
x =12

# %%
print(x)
type(x)
# Out:
# 12
# int

# %%
y = 0.001

# %%
print(y)
type(x)
# Out:
# 0.001
# int

# %%
z = "hello"

# %%
print(z)
# Out:
# hello

# %%
type(z)
# Out:
# str

# %% [markdown]
# Operators

# %%
# mathematical oprators

# %%
# Addition : +

# %%
a = 12097
b = 1234

# %%
c = a + b
c
# Out:
# 13331

# %%
10 + 20
# Out:
# 30

# %%
print("The  addition of two numbers is ", 123+432)
# Out:
# The  addition of two numbers is  555

# %%
print('The addition is : ',c)
# Out:
# The addition is :  13331

# %%
# Substraction : -

# %%
d = a-b
print(d)
# Out:
# 10863

# %%
100 - 10
# Out:
# 90

# %%
# multiplication : *

# %%
mul = a*10
mul
# Out:
# 120970

# %%
230098*1
# Out:
# 230098

# %%
# division : /

# %%
12/2
# Out:
# 6.0

# %%
a/2
# Out:
# 6048.5

# %%
# floor division : //

# %%
5//2
# Out:
# 2

# %%
# exponential :**

# %%
3 ** 2
# Out:
# 9

# %%
4 ** 4
# Out:
# 256

# %%
# modulus : %

# %%
12 % 3
# Out:
# 0

# %%
12 % 5
# Out:
# 2

# %%
# Comparison Operators
num1 = 100
num2 = 200

# %%
# greater than
num1 > num2
# Out:
# False

# %%
# less than
num1 < num2
# Out:
# True

# %%
num1 == num2
# Out:
# False

# %%
num1 != num2
# Out:
# True

# %%
num1 is num2
# Out:
# False

# %%
num2 is 100
# Out:
# False

# %%
num1 is 100
# Out:
# True

# %%
num1 >= num1
# Out:
# True

# %%
# boolean datatype
x = True
y = False
x
y
# Out:
# False

# %%
print(x)
print(y)
# Out:
# True
# False

# %%
# logical operators
# and
x and y
# Out:
# False

# %%
False and False
# Out:
# False

# %%
# or
x or y
# Out:
# True

# %%
# not
not x
# Out:
# False

# %% [markdown]
# Practical Coding Questions

# %%
#1

age = 29
height = 6.1
name = "Raj"

print("Name :",name)
print("Age : ",age)
print("Height : ",height)
# Out:
# Name : Raj
# Age :  29
# Height :  6.1

# %%
#2

int1 = 562
int2 = 231
result = int1 + int2

print("Addition of two numbers is",result)
# Out:
# Addition of two numbers is 793

# %%
#3

price_of_item = 918.76
item_name = "Data Science Book"

print("Item name ",item_name, "Price of Item ", price_of_item)
print("what is the price of",item_name, "in pune ?", price_of_item)
# Out:
# Item name  Data Science Book Price of Item  918.76
# what is the price of Data Science Book in pune ? 918.76

# %% [markdown]
# Strings

# %%
# str
# Strings

# %%
name = 'Ethans'

# %%
type(name)
# Out:
# str

# %%
num = '12356'

# %%
num + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
num + name
# Out:
# '12356Ethans'

# %%
num + ' ' + name
# Out:
# '12356 Ethans'

# %%
num * 2
# Out:
# '1235612356'

# %%
name * 2
# Out:
# 'EthansEthans'

# %%
name * + ' ' +(*2)
# Out:
#   Cell In[15], line 1
#     name * + ' ' +(*2)
#                    ^
# SyntaxError: cannot use starred expression here

# %%
name[1]
# Out:
# 't'

# %%
name[-5]
# Out:
# 't'

# %%
name[1:4] # slicing
# Out:
# 'tha'

# %%
name
# Out:
# 'Ethans'

# %%
len(name)
# Out:
# 6

# %%
name.upper()
# Out:
# 'ETHANS'

# %%
name.lower()
# Out:
# 'ethans'

# %%
name.capitalize()
# Out:
# 'Ethans'

# %%
name1 = name.capitalize()

# %%
name1
# Out:
# 'Ethans'

# %%
data = "Hello all, We are learning python"

# %%
data.count('o')
# Out:
# 2

# %%
data.count(' ')
# Out:
# 5

# %%
data.count("n")
# Out:
# 3

# %%
data.count(' is')
# Out:
# 0

# %%
data.count(' are')
# Out:
# 1

# %%
data.capitalize()
# Out:
# 'Hello all, we are learning python'

# %%
data.capitalize("python")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data.capitalize("python")
#
# TypeError: str.capitalize() takes no arguments (1 given)

# %%
dir(data)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
data.casefold()
# Out:
# 'hello all, we are learning python'

# %%
help(data.casefold)
# Out:
# Help on built-in function casefold:
#
# casefold() method of builtins.str instance
#     Return a version of the string suitable for caseless comparisons.

# %%
# endswith
data.endswith(".")
# Out:
# False

# %%
help(data.endswith)
# Out:
# Help on built-in function endswith:
#
# endswith(suffix[, start[, end]], /) method of builtins.str instance
#     Return True if the string ends with the specified suffix, False otherwise.
#
#     suffix
#       A string or a tuple of strings to try.
#     start
#       Optional start position. Default: start of the string.
#     end
#       Optional stop position. Default: end of the string.

# %%
# startswith
data.startswith('H')
# Out:
# True

# %%
help(data.startswith)
# Out:
# Help on built-in function startswith:
#
# startswith(prefix[, start[, end]], /) method of builtins.str instance
#     Return True if the string starts with the specified prefix, False otherwise.
#
#     prefix
#       A string or a tuple of strings to try.
#     start
#       Optional start position. Default: start of the string.
#     end
#       Optional stop position. Default: end of the string.

# %%
data.join("data")
# Out:
# 'dHello all, We are learning pythonaHello all, We are learning pythontHello all, We are learning pythona'

# %%
'a'.join("hello")
# Out:
# 'haealalao'

# %%
help(data.join)
# Out:
# Help on built-in function join:
#
# join(iterable, /) method of builtins.str instance
#     Concatenate any number of strings.
#
#     The string whose method is called is inserted in between each given string.
#     The result is returned as a new string.
#
#     Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'

# %%
data.replace("python","SQL")
# Out:
# 'Hello all, We are learning SQL'

# %%
help(data.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, /, count=-1) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
data.split()
# Out:
# ['Hello', 'all,', 'We', 'are', 'learning', 'python']

# %%
help(data.split)
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including \n \r \t \f and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits.
#         -1 (the default value) means no limit.
#
#     Splitting starts at the front of the string and works to the end.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.

# %%
name
# Out:
# 'Ethans'

# %%
name[::-1]
# Out:
# 'snahtE'

# %%
# Reverse String

d = "Data Science"
d1 = d.split()
d1
d2 = d1[::-1]
d2
" ".join(d2)
# Out:
# 'Science Data'

# %% [markdown]
# String Realted Questions

# %%
#1

name = "Prasanna Rahangdale"
age = 25
height = 5.11

print(f"I am {name} and I'm {age} old and {height} feet long")
# Out:
# I am Prasanna Rahangdale and I'm 25 old and 5.11 feet long

# %%
#2

name[0]
print(name[0])
name[-1]
print(name[-1])

print("-----------------------")

print(name.upper())

print("-----------------------")

print(name.replace('a', '*'))
print(name.replace('e', '*'))
print(name.replace('i', '*'))
print(name.replace('o', '*'))
print(name.replace('u', '*'))
print(name.replace('a','*').replace('e','*').replace('i','*').replace('o','*').replace('u','*'))

print("-----------------------")

sum = age + height
diff = age - height
mul = age * height
div = age /height

print(sum)
print(diff)
print(mul)
print(div)
# Out:
# P
# e
# -----------------------
# PRASANNA RAHANGDALE
# -----------------------
# Pr*s*nn* R*h*ngd*le
# Prasanna Rahangdal*
# Prasanna Rahangdale
# Prasanna Rahangdale
# Prasanna Rahangdale
# Pr*s*nn* R*h*ngd*l*
# -----------------------
# 30.11
# 19.89
# 127.75000000000001
# 4.892367906066536

# %% [markdown]
# Data Structures

# %%
lst1 = [2,5,8,90,0.234,2.0,'apple', 'python']

# %%
lst1
# Out:
# [2, 5, 8, 90, 0.234, 2.0, 'apple', 'python']

# %%
type(lst1)
# Out:
# list

# %%
lst1
# Out:
# [2, 5, 8, 90, 0.234, 2.0, 'apple', 'python']

# %%
lst1[2:9]
# Out:
# [8, 90, 0.234, 2.0, 'apple', 'python']

# %%
lst1[:5]
# Out:
# [2, 5, 8, 90, 0.234]

# %%
dir(lst1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
#append
lst1
# Out:
# [2, 5, 8, 90, 0.234, 2.0, 'apple', 'python']

# %%
lst1.append('Data Science')

# %%
lst1
# Out:
# [2,
#  5,
#  8,
#  90,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data SCience',
#  'Data Science']

# %%
lst1.insert(6, 100)

# %%
lst1
# Out:
# [2,
#  5,
#  8,
#  90,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data SCience',
#  'Data Science']

# %%
lst2 = lst1.copy()
lst2
# Out:
# [2,
#  5,
#  8,
#  90,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data SCience',
#  'Data Science']

# %%
lst2.clear()
lst2
# Out:
# []

# %%
len(lst1)
# Out:
# 12

# %%
lst1.remove('Data SCience')
lst1
# Out:
# [2, 5, 8, 90, 0.234, 2.0, 100, 100, 'apple', 'python', 'Data Science']

# %%
lst1.count(5)
# Out:
# 1

# %%
L = [77, 88, 99]
L
# Out:
# [77, 88, 99]

# %%
lst1.append(L)
lst1
# Out:
# [2,
#  5,
#  8,
#  90,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data Science',
#  [77, 88, 99]]

# %%
lst1.extend(L)
lst1
# Out:
# [2,
#  5,
#  8,
#  90,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data Science',
#  [77, 88, 99],
#  77,
#  88,
#  99]

# %%
lst1.index('apple')
# Out:
# 8

# %%
lst2 = [44,7,9,1,3,67]
lst2.sort() # Sorting automatically done in ascending order.
lst2
# Out:
# [1, 3, 7, 9, 44, 67]

# %%
lst2.sort(reverse = True) # Sorting towards descending order.
lst2
# Out:
# [67, 44, 9, 7, 3, 1]

# %%
lst2.reverse() # to change the position of data from last to first...
lst2
# Out:
# [67, 44, 9, 7, 3, 1]

# %%
lst1.reverse()
lst1
# Out:
# [2,
#  5,
#  8,
#  90,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data Science',
#  [77, 88, 99],
#  77,
#  88,
#  99]

# %%
L1 = [34, 7, 8, 11, 91, 567]
L1.reverse() # to change the position of data from last to first...
L1
# Out:
# [567, 91, 11, 8, 7, 34]

# %%
L2 = ['python','SQL', 'Java', 'Spring', 'cpp']
L2.reverse()
L2
# Out:
# ['cpp', 'Spring', 'Java', 'SQL', 'python']

# %%
lst1.pop(3)
# Out:
# 90

# %%
lst1
# Out:
# [2,
#  5,
#  8,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data Science',
#  [77, 88, 99],
#  77,
#  88,
#  99]

# %%
lst1.pop()
lst1
# Out:
# [2,
#  5,
#  8,
#  0.234,
#  2.0,
#  100,
#  100,
#  'apple',
#  'python',
#  'Data Science',
#  [77, 88, 99],
#  77,
#  88]

# %%
lst1.remove(-3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 lst1.remove(-3)
#
# ValueError: list.remove(x): x not in list

# %%
lst1.remove(9999)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 lst1.remove(9999)
#
# ValueError: list.remove(x): x not in list

# %%
L3 = [10, 20, 30, 40, 50]
L4 = [9,81, 54, 21, 78, 99, 13, "rahul"]
L3 + L4
# Out:
# [10, 20, 30, 40, 50, 9, 81, 54, 21, 78, 99, 13, 'rahul']

# %%
sum(L3)
# Out:
# 150

# %%
lst3 = [3,3,3,7,8,5]
lst3.remove(3)
lst3
# Out:
# [3, 3, 7, 8, 5]

# %%
a = 10
b = 10
print(a,b)
print(id(a),id(b))
# Out:
# 10 10
# 140725839963336 140725839963336
