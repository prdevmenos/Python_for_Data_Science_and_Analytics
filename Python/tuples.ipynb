# %% [raw]
# # Tuple
# One dimensional
# Indexed
# Immutable(can't change)
# more fast than list
# duplicates are allowed.
# we will write tuple inside()
# it supports different datatype.

# %%
tup1 = (1,3,4,5,6,'SQL')

# %%
tup1
# Out:
# (1, 3, 4, 5, 6, 'SQL')

# %%
type(tup1)
# Out:
# tuple

# %%
l =[3,5,7,90,22,44]
type(l)
# Out:
# list

# %%
t = tuple(l) # typecasting : here list datatype convert into tuple datatype.
type(t)
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (3, 5, 7, 90, 22, 44)

# %%
l2 = list(t) # typecasting : here tuple datatype convert into list datatype.
type(l2)
print(type(l2))
print(l2)
# Out:
# <class 'list'>
# [3, 5, 7, 90, 22, 44]

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t.count(7)
# Out:
# 1

# %%
t.index(7)
# Out:
# 2

# %%
t[2:6]
# Out:
# (7, 90, 22, 44)

# %%
# Imp
tu1 = (2,)
tu1
# Out:
# (2,)
