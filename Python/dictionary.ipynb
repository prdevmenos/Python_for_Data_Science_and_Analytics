# %%
# dictionary

# %%
D1 = {
    'name' : "Raj",
    'age' : 25,
    'salary' : 250000,
    'designation' : "architect"
}

# %%
D1
# Out:
# {'name': 'Raj', 'age': 25, 'salary': 250000, 'designation': 'architect'}

# %%
D1['city'] = "Pune"

# %%
D1
# Out:
# {'name': 'Raj',
#  'age': 25,
#  'salary': 250000,
#  'designation': 'architect',
#  'city': 'Pune'}

# %%
dir(D1)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
D1.keys()
# Out:
# dict_keys(['name', 'age', 'salary', 'designation', 'city'])

# %%
D1.values()
# Out:
# dict_values(['Raj', 25, 250000, 'architect', 'Pune'])

# %%
D1.items()
# Out:
# dict_items([('name', 'Raj'), ('age', 25), ('salary', 250000), ('designation', 'architect'), ('city', 'Pune')])

# %%
D1.fromkeys("Raj")
# Out:
# {'R': None, 'a': None, 'j': None}

# %%
D1.fromkeys("name")
# Out:
# {'n': None, 'a': None, 'm': None, 'e': None}

# %%
D1.popitem()
# Out:
# ('city', 'Pune')

# %%
D1.pop("name")
# Out:
# 'Raj'

# %%
D1
# Out:
# {'age': 25, 'salary': 250000, 'designation': 'architect'}

# %%
D1['salary']
# Out:
# 250000

# %%
D1.get("Raj")
D1
# Out:
# {'age': 25, 'salary': 250000, 'designation': 'architect'}

# %%
L1 = [1,3,4,5,6,7]
L2 = [11,22,33,44,55,66,77]

# %%
student = {
    'M1' : L1, 'M2' : L2
}

# %%
student
# Out:
# {'M1': [1, 3, 4, 5, 6, 7], 'M2': [11, 22, 33, 44, 55, 66, 77]}

# %%
student['M2']
# Out:
# [11, 22, 33, 44, 55, 66, 77]

# %%
student['M2'] + student['M2']
# Out:
# [11, 22, 33, 44, 55, 66, 77, 11, 22, 33, 44, 55, 66, 77]

# %%
student['M1'] + student['M2']
# Out:
# [1, 3, 4, 5, 6, 7, 11, 22, 33, 44, 55, 66, 77]

# %%
#nested dictionary
school = {
    'stud1':{'test1' : [15, 18, 16], 'test2' : [19, 18, 17]},
    'stud2':{'test1' : [20, 19, 18], 'test2' : [12, 13, 18]}
}

# %%
school
# Out:
# {'stud1': {'test1': [15, 18, 16], 'test2': [19, 18, 17]},
#  'stud2': {'test1': [20, 19, 18], 'test2': [12, 13, 18]}}

# %%
school['stud2']['test1']
# Out:
# [20, 19, 18]

# %%
school['stud1']['test2']
# Out:
# [19, 18, 17]
