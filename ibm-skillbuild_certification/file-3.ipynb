# %% [markdown]
# # Object and Classes

# %% [markdown]
# ### Methods
#
# - A class or type's methods are functions that every instance of class or type provides
# - It's how we interact object
# - Sorting is an example of method that are interacting with data in the object

# %%
Ratings = [2,9,4,5,6,3,6,8,9,1,10,5,10]

# %%
Ratings.sort()
Ratings
# Out:
# [1, 2, 3, 4, 5, 5, 6, 6, 8, 9, 9, 10, 10]

# %%
Ratings.sort(reverse=True)
Ratings
# Out:
# [10, 10, 9, 9, 8, 6, 6, 5, 5, 4, 3, 2, 1]

# %%
Ratings.reverse()
Ratings
# Out:
# [10, 10, 9, 9, 8, 6, 6, 5, 5, 4, 3, 2, 1]

# %% [markdown]
# ## Create Our Own Methods : Defining Classes

# %% [markdown]
# - self: the self parameter refers to the newly created instance of the class.

# %%
class Circle(object):
    def __init__(self,radius,color):
        self.radius = radius
        self.color = color 

    def add_radius(self,r):
        self.radius = self.radius + r
        return(self.radius)

# %%
class Rectangle(object):
    def __init__(self,length,breadth,color):
        self.length = length
        self.breadth = breadth
        self.color = color

# %%
c1 = Circle(2,'red')
c1.add_radius(8)
# Out:
# 10

# %%
class Car(object):
    def __init__(self,make,model,color):
        self.make=make;
        self.model=model;
        self.color=color;
        self.owner_number=0 
    def car_info(self):
        print("make: ",self.make)
        print("model:", self.model)
        print("color:",self.color)
        print("number of owners:",self.owner_number)
    def sell(self):
        self.owner_number=self.owner_number+1

# %%
# Import the library

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # The Circle Class

# %%
# Create a class Circle

class Circle(object):
    
    # Constructor
    def __init__(self, radius=3, color='blue'):
        self.radius = radius
        self.color = color 
    
    # Method
    def add_radius(self, r):
        self.radius = self.radius + r
        return(self.radius)
    
    # Method
    def drawCircle(self):
        plt.figure(figsize=(3,3))
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
        plt.axis('scaled')
        plt.show()

# %%
# Create an object RedCircle

RedCircle = Circle(10, 'red')

# %%
# Find out the methods can be used on the object RedCircle

dir(RedCircle)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_radius',
#  'color',
#  'drawCircle',
#  'radius']

# %%
# Print the object attribute radius

RedCircle.radius
# Out:
# 10

# %%
# Print the object attribute color

RedCircle.color
# Out:
# 'red'

# %%
# Set the object attribute radius

RedCircle.radius = 1
RedCircle.radius
# Out:
# 1

# %%
# Call the method drawCircle

RedCircle.drawCircle()

# %%
# Use method to change the object attribute radius

print('Radius of object:',RedCircle.radius)
RedCircle.add_radius(2)
print('Radius of object of after applying the method add_radius(2):',RedCircle.radius)
RedCircle.add_radius(5)
print('Radius of object of after applying the method add_radius(5):',RedCircle.radius)
# Out:
# Radius of object: 1
# Radius of object of after applying the method add_radius(2): 3
# Radius of object of after applying the method add_radius(5): 8

# %%
# Create a blue circle with a given radius

BlueCircle = Circle(radius=100)

# %%
# Print the object attribute radius

BlueCircle.radius
# Out:
# 100

# %%
# Print the object attribute color

BlueCircle.color
# Out:
# 'blue'

# %%
# Call the method drawCircle

BlueCircle.drawCircle()

# %% [markdown]
# # The Rectangle Class

# %%
# Create a new Rectangle class for creating a rectangle object

class Rectangle(object):
    
    # Constructor
    def __init__(self, width=2, height=3, color='r'):
        self.height = height 
        self.width = width
        self.color = color
    
    # Method
    def drawRectangle(self):
        plt.figure(figsize=(3,3))
        plt.gca().add_patch(plt.Rectangle((0, 0), self.width, self.height ,fc=self.color))
        plt.axis('scaled')
        plt.show()

# %%
# Create a new object rectangle

SkinnyBlueRectangle = Rectangle(2, 3, 'blue')

# %%
# Print Object Attribute Height

SkinnyBlueRectangle.height
# Out:
# 3

# %%
# Print Object Attribute Width

SkinnyBlueRectangle.width
# Out:
# 2

# %%
# Print Object Attribute Color

SkinnyBlueRectangle.color
# Out:
# 'blue'

# %%
# Use the drawRectangle method to draw the shape

SkinnyBlueRectangle.drawRectangle()

# %%
# Create a new object rectangle

FatYellowRectangle = Rectangle(20, 5, 'yellow')

# %%
# print the object attribute height
FatYellowRectangle.height
# Out:
# 5

# %%
# print the object attribute width
FatYellowRectangle.width
# Out:
# 20

# %%
# Use the drawRectangle method to draw the shape

FatYellowRectangle.drawRectangle()

# %% [markdown]
# <center>
#
# # Scenario: Car dealership's inventory management system
#
# </center>

# %% [markdown]
# You are working on a Python program to simulate a car dealership's inventory management system. The system aims to model cars and their attributes accurately.

# %% [markdown]
# ### Task-1. You are tasked with creating a Python program to represent vehicles using a class. Each car should have attributes for maximum speed and mileage.

# %%
class Vehicles(object):
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

# %% [markdown]
# ### Task-2. Update the class with the default color for all vehicles," white".

# %%
class Vehicles(object):
    color = "white"

    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

# %% [markdown]
# ### Task-3. Additionally, you need to create methods in the Vehicle class to assign seating capacity to a vehicle.

# %%
#Type your code here
class Vehicles(object):
    color = "white"

    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        self.seat_capacity = None

    def assign_seat_capacity(self,seat_capacity):
        self.seat_capacity = seat_capacity

# %% [markdown]
# ### Task-4. Create a method to display all the properties of an object of the class.

# %%
#Type your code here
class Vehicles(object):
    color = "white"

    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        self.seat_capacity = None

    def assign_seat_capacity(self,seat_capacity):
        self.seat_capacity = seat_capacity

    def display(self):
        print("Properties of the Vehicle")
        print("Color:",self.color)
        print("Maximum Speed:", self.max_speed)
        print("Mileage:", self.mileage)
        print("Seating Capacity:", self.seat_capacity)
        print(f"The Vehicle Color is {self.color} consists seat capacity :{self.seat_capacity}, maximum speed :{self.max_speed} and mileage :{self.mileage}")

# %% [markdown]
# ### Task-5. Additionally, you need to create two objects of the Vehicle class object that should have a max speed of 200kmph and mileage of 20kmpl with five seating capacities, and another car object should have a max speed of 180kmph and mileage of 25kmpl with four seating capacities.

# %%
V1 = Vehicles('200kmph','20kmpl')
V1.assign_seat_capacity(5)
V1.display()

V2 = Vehicles('180kmph','25kmpl')
V1.assign_seat_capacity(4)
V2.display()
# Out:
# Properties of the Vehicle
# Color: white
# Maximum Speed: 200kmph
# Mileage: 20kmpl
# Seating Capacity: 5
# The Vehicle Color is white consists seat capacity :5, maximum speed :200kmph and mileage :20kmpl
# Properties of the Vehicle
# Color: white
# Maximum Speed: 180kmph
# Mileage: 25kmpl
# Seating Capacity: None
# The Vehicle Color is white consists seat capacity :None, maximum speed :180kmph and mileage :25kmpl
