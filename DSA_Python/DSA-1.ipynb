# %%
print("Hello, India")
# Out:
# Hello, India

# %% [markdown]
# ### Variables

# %%
a = 10
a = 'Hello'

print(a)
# Out:
# Hello

# %%
a1 = int(input("Enter number :"))
print(a1)
# Out:
# Enter number : 10
# 10

# %% [markdown]
# ### Operators

# %%
# Operators : +, -, *, /, %, ^, //

a = 10
b = 5
c = a + b

print(a + b)
print(c)
# Out:
# 15
# 15

# %%
a1 = int(input("Enter a number :"))
b1 = int(input("Enter a number :"))

c1 = a1 + b1

print("The sum of two numbers is", c)
# Out:
# Enter a number : 10
# Enter a number : 5
# The sum of two numbers is 15

# %%
# Product of three numbers

p = int(input("Enter a number :"))
q = int(input("Enter a number :"))
r = int(input("Enter a number :"))

product = p * q * r
print("The Product of three numbers are", product)
# Out:
# Enter a number : 12
# Enter a number : 3
# Enter a number : 5
# The Product of three numbers are 180

# %%
# Average of two numbers

m = int(input("Enter a number :"))
n = int(input("Enter a number :"))

avg = (m + n)/2
print("The average of two numbers is :", avg)
# Out:
# Enter a number : 60
# Enter a number : 50
# The average of two numbers is : 55.0
