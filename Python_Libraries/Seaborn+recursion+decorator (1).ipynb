# %%
import seaborn as sns

# %%
# dataset available already
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# seaborn already inbuild dataset
import seaborn as sns
data = sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.info() # it will give complete information about th dataset which we are using
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
DD=data.drop_duplicates()

# %%
DD.duplicated().sum()
# Out:
# np.int64(0)

# %%
DD.duplicated().sum()
# Out:
# np.int64(0)

# %%
DD['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    61
# Fri     19
# Name: count, dtype: int64

# %%
DD.head(2) # first 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
DD.tail(2) # last 5 rows
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
DD.mode()
# Out:
#    total_bill  tip   sex smoker  day    time  size
# 0       13.42  2.0  Male     No  Sat  Dinner     2

# %%
# Bar PLot
sns.barplot(x='day',y='tip',data=DD)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# create a side by side bar plot using seaborn between day & total bill 
sns.barplot(x='day',y='total_bill',hue='sex',data=DD)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='total_bill',y='day',hue='sex',data= data)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(x='total_bill',y='day',hue='sex',data= data,palette='magma')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# day vs tip
import matplotlib.pyplot as plt
sns.barplot(x='day',y='tip',data=data,palette='spring')   
plt.show()
# Out:
# C:\Users\rahan\AppData\Local\Temp\ipykernel_17792\1891806098.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day',y='tip',data=data,palette='spring')

# %%
# jointplot
sns.jointplot(x='tip',y='total_bill',palette='spring',data=DD)

# %%
sns.jointplot(x='tip',y='total_bill',palette='spring',data=data,kind='hex')
plt.show()

# %%
sns.jointplot(x='tip',y='total_bill',palette='spring',data=DD,kind='reg')
plt.show()

# %%
c =DD.corr(numeric_only = True)
sns.heatmap(c,annot = True)
# Out:
# <Axes: >

# %%
# pairplot()
# work on numerical data only
sns.pairplot(data)

# %%
sns.pairplot(data,hue='sex')

# %%
# displot() is use for finding the normality of data or distribution of data.
import warnings
warnings.filterwarnings('ignore')
sns.distplot(data['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(data['tip'],hist=False,color='g')
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # What are the docstrings in Python
# Python documentation strings (or docstrings) provide a convenient way of associating documentation with Python modules, functions, classes, and methods. It’s specified in source code that is used, like a comment, to document a specific segment of code. Unlike conventional source code comments, the docstring should describe what the function does, not how.
#
# Declaring Docstrings: The docstrings are declared using ”’triple single quotes”’ or “”” triple double quotes “”” just below the class, method, or function declaration. All functions should have a docstring.
# Accessing Docstrings: The docstrings can be accessed using the __doc__ method of the object or using the help function. The below examples demonstrate how to declare and access a docstring.

# %%
def my_function():
    '''Demonstrates triple double quotes
    docstrings and does nothing really.'''
 
    return None

print("Using __doc__:")
print(my_function.__doc__)
# Out:
# Using __doc__:
# Demonstrates triple double quotes
# docstrings and does nothing really.

# %% [markdown]
# # Recursion
# Python also accepts function recursion, which means a defined function can call itself.
#
# Recursion is a common mathematical and programming concept. It means that a function calls itself. This has the benefit of meaning that you can loop through data to reach a result.
#
# In this example, tri_recursion() is a function that we have defined to call itself ("recurse"). We use the k variable as the data, which decrements (-1) every time we recurse. The recursion ends when the condition is not greater than 0 (i.e. when it is 0).

# %%
# Program to print factorial of a number recursively.

# Recursive function
def recursive_factorial(n):
  if n == 1:
      return n
  else:
      return n * recursive_factorial(n-1)

# %%
recursive_factorial(5)
# Out:
# 120

# %% [markdown]
# # Generator Function in Python
# A generator function in Python is defined like a normal function, but whenever it needs to generate a value, it does so with the yield keyword rather than return. If the body of a def contains yield, the function automatically becomes a Python generator function.

# %%
# A generator function that yields 1 for first time,
# 2 second time and 3 third time
def simpleGeneratorFun():
    yield 1            
    yield 22            
    yield 3

# %%
simpleGeneratorFun()
# Out:
# <generator object simpleGeneratorFun at 0x000001E569E2EE50>

# %%
# Driver code to check above generator function
for value in simpleGeneratorFun(): 
    print(value)
# Out:
# 1
# 22
# 3

# %% [markdown]
# # Decorators
# In Decorators, functions are taken as the argument into another function and then called inside the wrapper function.

# %%
# example 1
def print_msg(massage):
    greeting = 'Hello'
    
    def printer():
        print(greeting,massage)
    printer()

# %%
print_msg('Python is a wonderfull programming language')
# Out:
# Hello Python is a wonderfull programming language

# %%
def print_msg(massage):
    greeting = 'Hello'
    
    def printer():
        print(greeting,massage)
        
    return printer

# %%
X = print_msg('Python is a wonderfull programming language')
X()
# Out:
# Hello Python is a wonderfull programming language

# %%
# Example 2
def printer():
    print('Hello world')

# %%
def display_msg(func):
    def inner():
        print('Executing',func.__name__, 'function')
        func()
        print('Execution completed')
    return inner

# %%
decorated_function = display_msg(printer)
decorated_function()
# Out:
# Executing printer function
# Hello world
# Execution completed

# %%
#Example 3 
def make_pretty(func):
    def inner():
        print("I got decorated")
        func()
    return inner


def ordinary():
    print("I am ordinary")

# %%
Y= make_pretty(ordinary)
Y()
# Out:
# I got decorated
# I am ordinary

# %%
# decorate the ordinary function
decorated_func = make_pretty(ordinary)

# %%
# call the decorated function
decorated_func()
# Out:
# I got decorated
# I am ordinary

# %%
def decorator(func):
    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

@decorator # Applying the decorator to a function
def greet():
    print("Hello, World!")

# %%
greet()
# Out:
# Before calling the function.
# Hello, World!
# After calling the function.
